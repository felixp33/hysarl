# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as mcolors


def plot_std_compositions(std_dict, figsize=(10, 6), save_path=None, title="Standard Deviations by Composition"):
    """
    Plots standard deviations from different sampling compositions as line plots.

    Parameters:
    std_dict (dict): A dictionary where keys are composition labels and values are arrays of standard deviations.
    figsize (tuple): Figure size as (width, height) in inches.
    save_path (str, optional): Path to save the figure. If None, the figure is displayed but not saved.
    title (str): Title for the plot.

    Returns:
    fig, ax: The figure and axis objects for further customization if needed.
    """
    fig, ax = plt.subplots(figsize=figsize)

    # Generate a color progression from light to dark blue
    compositions = list(std_dict.keys())
    num_compositions = len(compositions)

    # Create a color list from light to dark blue
    blues = plt.cm.Blues(np.linspace(0.3, 0.9, num_compositions))

    # Sort the compositions based on your desired order
    # This example assumes compositions are named with numerical indicators like 'm20', 'm40', etc.
    # You might need to adjust this sorting logic based on your specific composition naming
    sorted_compositions = sorted(
        compositions, key=lambda x: int(x[1:]) if x[1:].isdigit() else 0)

    for i, comp in enumerate(sorted_compositions):
        if comp in std_dict:
            std_values = std_dict[comp]
            episodes = np.arange(len(std_values))

            # Plot the standard deviation line
            ax.plot(
                episodes,
                std_values,
                label=comp,
                color=blues[i],
                linewidth=2
            )

    ax.set_xlabel('Episode')
    ax.set_ylabel('Standard Deviation')
    ax.set_title(title)
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    return fig, ax


# Example usage
std_compositions = {
    'm20': [0.8, 0.7, 0.65, 0.6, 0.55],
    'm40': [0.7, 0.65, 0.6, 0.55, 0.5],
    'm60': [0.6, 0.55, 0.5, 0.45, 0.4],
    'm80': [0.5, 0.45, 0.4, 0.35, 0.3],
    'm100': [0.4, 0.35, 0.3, 0.25, 0.2]
}

# Plot the standard deviations
fig, ax = plot_std_compositions(std_compositions)
plt.show()

# %%
# Sample dictionary of arrays
sample_data = {
    'm100': [1, 3, 5, 7, 9],
    'm90': [2, 4, 6, 8, 10],
    'm80': [5, 3, 8, 6, 7]
}

# Call the function to plot the data
plot_dict_of_arrays(sample_data)
